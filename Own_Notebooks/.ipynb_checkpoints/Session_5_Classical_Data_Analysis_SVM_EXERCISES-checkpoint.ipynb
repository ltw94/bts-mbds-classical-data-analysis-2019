# %% [markdown]
# ![BTS](https://github.com/vfp1/bts-mbds-data-science-foundations-2019/raw/master/sessions/img/Logo-BTS.jpg)
#
# # Session 5: Support Vector Machines EXERCISES
#
# ### Victor F. Pajuelo Madrigal <victor.pajuelo@bts.tech> - Classical Data Analysis (09-01-2020)
#
# Open this notebook in Google Colaboratory: [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vfp1/bts-mbds-classical-data-analysis-2019/blob/master/05_SVM/Session_5_Classical_Data_Analysis_SVM.ipynb)

# %% [markdown]
# ## Exercise one [NO CODE]
#
#
#
# 1.   What is a support vector?
# 2.   Why it is important to scale inputs when using the SVM?
# 3. Should you use dual=True or dual=False when training a model with millions of samples but hundreds of features?

# %% [markdown]
# 1. The support vector lines are the longest distance possible between the closest variables. They are equidistant from the hyperplane lines which represents the classifiers decision function (expressed as w*x -b = 0). The two support vectors are expressed as w*x - b = 1 and w*x - b = -1.
#
# 2. The SVM constructs the hyperplane which (as discussed in answer 1) such that it maximises the largest possible distance between points (of the opposite classification). It therefore follows that if the dimensions have different ranges, the dimension with the much greater range of values influences the distance more than other dimensions. We therefore need to scale the features so that all features have the similar level of influence when calculating the distance in the construction of the hyperplane.
#
# 3. In optimization theory, the "duality principle" states that for any primaral (primal here referring to a minimization problem) there is a "dual problem" that can be solved to obtain solutions to the primal. The dual solution - unlike the primal - is a maximization problem. The SVC class in Sklearn assumes that the number of features == number of samples. Given this, there is no need for the duality parameter. However with the LinearSVC class, there is the danger of polynomial expansion, and therefore the duality parameter is included here. In the case where the number of samples > number of features, we set the duality as False.

# %% [markdown]
# ## Exercise two [NECESSARY]
#
# Train a SVM classifier on the datasets shown in class (not the regression one). Take special care with the hyperparameters for multiclassification, C and other hyperparameters that we discussed. You may want to tune the hyperparameters using smaller validation sets to speed up the process. What accuracy can you reach?
#
# In this exercise you need to:
#
# - Visualize and present the dataset
# - Apply the SVC to perform binary classification
# - Comment on the usage of the different kernels and the effect of the hyper-parameters (is always needed a nonlinear kernel?)
# - Visualize the results with a confusion matrix
# - Compute the accuracy score and comment on the results
# - Perform any other experiments that you can think of, always reason about the results!

# %% [markdown]
# ### Spam, Ham Dataset:

# %%
import numpy as np
import pandas as pd
import os
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.svm import SVC
from nltk.stem import SnowballStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
spam_mail = pd.read_csv('/Users/laurencewilliams/BTS/Classical_Data_Analysis/bts-mbds-classical-data-analysis-2019/Own_Notebooks/Data/spam.csv',
               encoding = 'ISO-8859-1', error_bad_lines=False)
spam_mail = spam_mail.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)

# %%
spam_mail.drop_duplicates(inplace=True)

# %%
spam_mail.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
spam_mail.isnull().sum()
# Out:
# v1    0
# v2    0
# dtype: int64

# %%
spam_mail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5169 entries, 0 to 5571
# Data columns (total 2 columns):
# v1    5169 non-null object
# v2    5169 non-null object
# dtypes: object(2)
# memory usage: 121.1+ KB

# %%
spam_mail['v2'].iloc[102]
# Out:
# "wow. You're right! I didn't mean to do that. I guess once i gave up on boston men and changed my search location to nyc, something changed. Cuz on my signin page it still says boston."

# %%
texts = []
labels = []
for i, label in enumerate(spam_mail['v1']):
    texts.append(spam_mail['v2'].iloc[i])
    if label == 'ham':
        labels.append(0)
    else:
        labels.append(1)

# %%
texts = np.asarray(texts)
labels = np.asarray(labels)
print("number of texts", len(texts))
print("number of labels", len(labels))
# Out:
# number of texts 5169
# number of labels 5169

# %% [markdown]
# Pre-processing text:

# %%
import spacy
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from sklearn.feature_extraction.text import CountVectorizer
nlp = spacy.load("en")
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS
parser = English()

# %%
def my_tokenization(text):
    mytokens = parser(text)
    mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
    mytokens = [word for word in mytokens if word not in stop_words and word not in punctuations]
    return mytokens

# %%
X = texts
Y = labels
lemma_vect = CountVectorizer(tokenizer=my_tokenization, min_df=3)
X_transformed = lemma_vect.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_transformed, labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (4135, 2311) (1034, 2311)
# (4135,) (1034,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %% [markdown]
# **Visualizer:**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def visualize(label):
    
    words = ''
    
    for msg in spam_mail[spam_mail['v1'] == label]['v2']:
        msg = msg.lower()
        words += msg + ' '
        
    wordcloud = WordCloud(width=600, height=400).generate(words)
    
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.title(label)
    plt.show()

# %%
visualize('ham')

# %%
visualize('spam')

# %% [markdown]
# **SVC Classifier:**

# %%
from sklearn.svm import SVC
model_ = SVC(kernel='linear', C=2.)

# %%
from datetime import datetime

t0 = datetime.now()
model_.fit(X_train, y_train)
print("train duration:", datetime.now() - t0)
# Out:
# train duration: 0:00:00.177321

# %%
print("Train:")
t0 = datetime.now()
print("train score:", model_.score(X_train, y_train), "duration:", datetime.now() - t0)
# Out:
# Train:
# train score: 0.9987908101571947 duration: 0:00:00.117823

# %%
print("Test:")
t0 = datetime.now()
print("test score:", model_.score(X_test, y_test), "duration:", datetime.now() - t0)
# Out:
# Test:
# test score: 0.9777562862669246 duration: 0:00:00.034670

# %% [markdown]
# ### Try with different hyperparameters(1):

# %% [markdown]
# **Poly kernel:**

# %%
from sklearn.svm import SVC
model_ = SVC(kernel='poly', C=2.)
model_.fit(X_train, y_train)
# Out:
# SVC(C=2.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print("train score:", model_.score(X_train, y_train))
print("test score:", model_.score(X_test, y_test))
# Out:
# train score: 0.98863361547763
# test score: 0.9323017408123792

# %% [markdown]
# **RBF kernel:**

# %%
model_ = SVC(kernel='rbf', C=2.)
model_.fit(X_train, y_train)
# Out:
# SVC(C=2.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print("train score:", model_.score(X_train, y_train))
print("test score:", model_.score(X_test, y_test))
# Out:
# train score: 0.9961305925030229
# test score: 0.97678916827853

# %% [markdown]
# **Grid Search:**

# %%
from sklearn.model_selection import GridSearchCV

model_ = SVC()

params = {'C': np.linspace(1,20,1),
          'kernel': ['rbf', 'linear']}

grid_search_cv = GridSearchCV(model_, params)

grid_search_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': array([1.]), 'kernel': ['rbf', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid_search_cv.best_params_)
print(grid_search_cv.best_estimator_)
# Out:
# {'C': 1.0, 'kernel': 'linear'}
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
grid_search_cv.best_params_['C']
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = grid_search_cv.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9787234042553191

# %% [markdown]
# ## Trying to automate this process: (1)

# %% [markdown]
# What needs to be done:
# * Compute this with the
# * Performa a grid search across all these types of vectorizations and append to a table

# %%
def my_tokenization(text):
    mytokens = parser(text)
    mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
    mytokens = [word for word in mytokens if word not in stop_words and word not in punctuations]
    return mytokens

# %%
#The three types I will test:
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
class Tester:
    
    def __init__(self, name, vectorizer):
        self.name = name
        self.vectorizer = vectorizer
    
    def split(self):
        X_ = self.vectorizer.fit_transform(X)
        X_train, X_test, y_train, y_test = train_test_split(X_, labels, test_size=0.2, random_state=4)
        
    def search(self):
        model = SVC()
        params = {'C': np.linspace(1,50,1),
          'kernel': ['rbf', 'linear', 'poly']}
        grid_search_cv = GridSearchCV(model, params)
        grid_search_cv = grid_search_cv.fit(X_train, y_train)
    
    def append(self):
        results_df = pd.DataFrame()
        results_df[self.name] = [grid_search_cv.best_params_['C'],
                                    grid_search_cv.best_params_['kernel'], 
                                    grid_search_cv.score(X_train, y_train),
                                    accuracy_score(y_test, grid_search_cv.predict(X_test))]
        return results_df

# %%
bags_of_words = Tester('Bag of Words', CountVectorizer(tokenizer=my_tokenization, min_df=3))
bags_of_words.split()
bags_of_words.search()
bags_of_words.append()
# Out:
#   Bag of Words
# 0            1
# 1       linear
# 2     0.997098
# 3     0.978723

# %%
tdif_ = Tester('TDIF', TfidfVectorizer(tokenizer = my_tokenization, min_df =3))
tdif_.split()
tdif_.search()
tdif_.append()
# Out:
#        TDIF
# 0         1
# 1    linear
# 2  0.997098
# 3  0.978723

# %%
hash_ = Tester('Hash', HashingVectorizer(tokenizer = my_tokenization))
hash_.split()
hash_.search()
hash_.append()
# Out:
# /Users/laurencewilliams/anaconda3/envs/bts36/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
#        Hash
# 0         1
# 1    linear
# 2  0.997098
# 3  0.978723

# %% [markdown]
# **Result:** Using grid search got the same results for the different vectorizers.

# %% [markdown]
# # Trying to automate this process: (2)

# %% [markdown]
# In this, we will use different algorithms (keep the same vectorizer) to test which gets the best result.
#
# The different algorithms I will consider:
# * SVC
# * Naive Bayes
# * Nearest Neighbor
#
# And just use the CountVectorizer

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# Note: If you want to automate this, the parameters are different for each one; therefore it is likely very difficult to automate this across.
#
# [TBD///]

# %% [markdown]
# ## Exercise three [OPTIONAL]
#
# *Try to solve this as an optional assignement, we will review the code in the following class*
#
# Support vector machines (SVMs) are a particularly powerful and flexible class of supervised algorithms. In this exercise, we will develop the intuition behind support vector machines and their use in classification problems.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# To begin with, let us generate the data for a linear classification problem. In order to do so use the `make_blobs` function from `sklearn`. We want to generate 50 samples, set the `random_state=0` and `cluster_std=0.6`. Finally plot the points with `plt.scatter`

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=50, centers=2, random_state=0, cluster_std=0.6)
print(X.shape)
print(y.shape)
# Out:
# (50, 2)
# (50,)

# %%
blob_scatter = plt.scatter(X[:, 0], X[:, 1], c=y)

# %% [markdown]
# A linear discriminative classifier would attempt to draw a straight line separating the two sets of data, and thereby create a model for classification. For two dimensional data like that shown here, this is a task we could do by hand. Think about a line that separates the two classes, how many are there? Which do you think would be the more appropiate given the data points? Draw some lines over this plot with slopes [1, 0.5, -0.2] and biases [0.65, 1.6, 2.9]. Use the `np.linespace` function to generate the x and the line equation
#
# $$y = mx + b$$
#
# for the y. Finally plot a "new point" in the coordinates (0.6, 2.1) with a red X.

# %%
(3.0*1+0.65)
# Out:
# 3.65

# %%
fig, ax = plt.subplots(3, figsize=(6,6))
x1 = np.linspace(-0.5, 3, num=50)
y1 = np.linspace(0.65, 3.65, num=50)
ax[0].scatter(x1, y1)
ax[0].set_title('Slope 1, bias 0.65')
x2 = np.linspace(-0.5, 3, num=50)
y2 = np.linspace(1.6, 3*0.5+1.6, num=50)
ax[1].scatter(x2, y2)
ax[1].set_title('Slope 0.5, bias 1.6')
x3 = np.linspace(-0.5, 3, num=50)
y3 = np.linspace(2.9, 3*-.2+2.9, num=50)
ax[2].scatter(x3, y3)
ax[2].set_title('Slope -0.2, bias 2.9')
# Out:
# Text(0.5, 1.0, 'Slope -0.2, bias 2.9')

# %% [markdown]
# ## SVM margins and support vectors
# These are three very different separators which, nevertheless, perfectly discriminate between these samples. Depending on which you choose, a new data point (e.g., the one marked by the "X" in this plot) will be assigned a different label!.
#
# Support vector machines offer one way to improve on this. The intuition is this: rather than simply drawing a line between the classes, we can draw around each line a margin of some width, up to the nearest point (no matter the class). To visualize this, let us repeat the same plot but adding some code to fill the margins. Use the method `plt.fill_between` with `color='#AAAAAA'`. The margins for each of the lines above are [0.33, 0.55, 0.2].

# %%
fig, ax = plt.subplots(3, figsize=(6,6))

#x1
x1 = np.linspace(-0.5, 3, num=50)
y1 = np.linspace(0.65, 3.65, num=50)
y11 = y1+0.33
y12 = y1-0.33
ax[0].fill_between(x1, y11, y12, color='#AAAAAA')
ax[0].scatter(x1, y1)
ax[0].set_title('Slope 1, bias 0.65')

#x2
x2 = np.linspace(-0.5, 3, num=50)
y2 = np.linspace(1.6, 3*0.5+1.6, num=50)
ax[1].fill_between(x2, y21, y22, color='#AAAAAA')
ax[1].scatter(x2, y2)
ax[1].set_title('Slope 0.5, bias 1.6')
y21 = y2+0.55
y22 = y2-0.55

#x3
x3 = np.linspace(-0.5, 3, num=50)
y3 = np.linspace(2.9, 3*-.2+2.9, num=50)
y31= y3+0.2
y32 = y3-0.2
ax[2].fill_between(x3, y31, y32, color='#AAAAAA')
ax[2].scatter(x3, y3)
ax[2].set_title('Slope -0.2, bias 2.9')
# Out:
# Text(0.5, 1.0, 'Slope -0.2, bias 2.9')

# %% [markdown]
# Now fit an SVM to this data. Use Scikit-Learn's support vector classifier to train an SVM model. For the time being, we will use a linear kernel and set the C parameter to a very large number like 1E10.

# %%
#datasets
X, y = make_blobs(n_samples=50, centers=2, random_state=0, cluster_std=0.6)

# %%
model_new = SVC(kernel='linear', C=1E10)
model_new.fit(X, y)
# Out:
# SVC(C=10000000000.0, break_ties=False, cache_size=200, class_weight=None,
#     coef0=0.0, decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# Now retrieve the support vectors from the learned model. Would you be able to identify them on the plot? Why are these the support vectors? Why are they important?

# %%
model_new.support_vectors_
# Out:
# array([[0.44359863, 3.11530945],
#        [2.33812285, 3.43116792],
#        [2.06156753, 1.96918596]])

# %%
plt.scatter(model_new.support_vectors_[:, 0], model_new.support_vectors_[:, 1])

# %% [markdown]
# This function will plot the decision boundaries of a model and the support vectors.

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""

    ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none',
                   edgecolors='blue')
        
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %% [markdown]
# Generate a scatter plot of the data set and use the previous function to draw the support vectors and the decision boundaries

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %% [markdown]
# A key to this classifier's success is that for the fit, only the position of the support vectors matter; any points further from the margin which are on the correct side do not modify the fit! Technically, this is because these points do not contribute to the loss function used to fit the model, so their position and number do not matter so long as they do not cross the margin.
#
# In order to see an example of this, simulate the points with the same random seed, but now simulate 120. Then train again the SVM and plot the decision boundaries. Which are the support vectors this time? Is this an expected result? Why?

# %%
X, y = make_blobs(n_samples=120, centers=2, random_state=0, cluster_std=0.6)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %% [markdown]
# * The support vectors are the same because there hardly more points that contribute to the extreme cases (that is, close to the support vector classification lines).
# * In other words: sheer quantity of new data added does not have much of an impact (unless it is extreme cases)

# %% [markdown]
# ## SVM softening the margins
# Now add a new point which is inside the decision boundary, say (-0.5, 2) to class 0, what do you expect will happen?

# %%
X, y = make_blobs(n_samples=120, centers=2, random_state=0, cluster_std=0.6)

#Add new point
X = np.append(X, [[-.5, 2]], axis = 0)
y = np.append(y, [0], axis = 0)

#Update model
model_new = SVC(kernel='linear', C=1E10)
model_new.fit(X, y)

#scatter
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %% [markdown]
# *We can see that in this case the support vecotrs have adjusted - it is a stepper classification line in order to suppor this ne w point.*

# %% [markdown]
# How about adding an even more outlier, like (0, 0) to class 0.

# %%
#Add new point
X = np.append(X, [[0, 0]], axis = 0)
y = np.append(y, [0], axis = 0)

#Update model
model_new = SVC(kernel='linear', C=1E10)
model_new.fit(X, y)

#scatter
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %% [markdown]
# What happened to the margin? Could we use this model if we had a red point further right? Why?
#
# * Here we can see that the model updates with smaller vector margins

# %% [markdown]
# What happened to the margin? Could we use this model if we had a red point further right? Why?
#
# Now, is there a way that we could try to make the SVM more robust to these possible outliers? Which one? Try to implement an SVM model with the same data modifying the C parameter. What do you observe?

# %% [raw]
# Modification of C Parameter (1):

# %% [markdown]
# The C parameter tells the SVM optimization how much you want to avoid misclassifying each training example. For large values of C, the optimization will choose a smaller-margin hyperplane if that hyperplane does a better job of getting all the training points classified correctly.
#
# * Therefore, if we want to make the SVM more robust to possible outlierws, we would opt for a larger C value (but this comes at the expense of less generalisation).

# %%
#Update model - change c = 1E10 to c = 1E11
model_new = SVC(kernel='linear', C=1E11)
model_new.fit(X, y)

#scatter
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %%
#Update model - change c = 1E10 to c = 1
model_new = SVC(kernel='linear', C=1)
model_new.fit(X, y)

#scatter
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %%
#Update model - change c = 1E10 to c = 1
model_new = SVC(kernel='linear', C=1E30)
model_new.fit(X, y)

#scatter
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_new)

# %% [markdown]
# ## SVM Kernels
# Now we have seen that SVM are very useful to find the optimal separating hyper-plane when your data is linearly separable. Even when you have some noise in the data set, you can tune the C-value to be able to adjust this. But what happens if your classes are not linearly separable? Is there a way we could overcome this draw-back? Let us generate a dataset that is not linearly separable. Use the `make_circles` method from `samples_generator` in sklearn. Generate 100 examples with `factor=.1, noise=.1, random_state=0`. Then generate a scatter plot to visualize the samples, use a different color for each class.

# %%
from sklearn.datasets import make_circles
X, y = make_circles(factor=0.1, noise=0.1, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (100, 2)
# (100,)

# %% [markdown]
# Now try to classify this data with a linear SVM, what do you expect will happen? Does this model capture the pattern of the classes? Plot the classification results with the `plot_svc_decision_function`

# %%
#fit model
model_circle = SVC(kernel='linear')
model_circle.fit(X, y)


#plot
plt.scatter(X[:, 0], X[:, 1], c=y)
plot_svc_decision_function(model_circle)

# %% [markdown]
# What could we do in order to make this dataset linearly separable? We can project it into a higher dimensional space. Note the similarity between this, and the polynomial regression. In order to have a better understanding of how kernels work, first implement a third axis with python with the following expression:
#
# $$x_3 = e^{-(x_1^2 + x_2^2)}$$
#
# Actually this is somewhat equivalent to the rbf kernel. You should name the new axis `x_3`

# %%
import numpy as np

# %%
X1 = X[:, 0]
X2 = X[:, 1]
x_3 = np.exp(-(X**2).sum(1))

# %% [markdown]
# Once you have implemented this 3rd axis, you may

# %%
from mpl_toolkits import mplot3d
from ipywidgets import interact, fixed

def plot_3D(elev=30, azim=30, X=X, y=y):
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], x_3, c=y, s=50, cmap='autumn')
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x_1')
    ax.set_ylabel('x_2')
    ax.set_zlabel('x_3')
    
interact(plot_3D, elev=[30, 0, 90], azip=(-180, 180),
         X=fixed(X), y=fixed(y));
# Out:
# interactive(children=(Dropdown(description='elev', options=(30, 0, 90), value=30), IntSlider(value=30, descrip…

# %% [markdown]
# Now use the SVM classifier but set the `kernel='rbf'` with high value for C and plot the results

# %%
#fit model
model_circle = SVC(kernel='rbf', C=1E6)
model_circle.fit(X, y)
# Out:
# SVC(C=1000000.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#plot
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model_circle)
plt.scatter(model_circle.support_vectors_[:, 0], model_circle.support_vectors_[:, 1], s=300)

# %% [markdown]
# ## Evaluating the classification results
# In order to assess the goodness of our model we need to compute some quantitative scores, we will review some of the most relevant. First, use the function `make_blobs` to generate a multilabel dataset. Generate 200 samples with 4 different classes set `random_state=0` and `cluster_std=0.6`

# %%
X, y = make_blobs(n_samples=200, centers = 4, random_state=0, cluster_std=0.6)
#plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
#plot_svc_decision_function(model_new)

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 2)
# (200,)

# %%
y
# Out:
# array([1, 2, 0, 3, 1, 0, 2, 0, 0, 0, 0, 1, 2, 2, 1, 0, 3, 3, 3, 1, 3, 2,
#        1, 2, 1, 1, 3, 1, 1, 0, 3, 0, 2, 1, 2, 0, 2, 0, 0, 3, 3, 3, 3, 0,
#        1, 2, 0, 3, 3, 0, 3, 2, 2, 3, 0, 3, 2, 1, 0, 1, 3, 0, 1, 0, 3, 0,
#        1, 3, 2, 2, 1, 1, 0, 0, 2, 3, 2, 2, 1, 1, 3, 0, 1, 2, 2, 0, 0, 1,
#        2, 2, 3, 3, 3, 0, 0, 1, 2, 3, 0, 0, 3, 1, 1, 3, 3, 2, 0, 1, 1, 0,
#        3, 2, 2, 1, 1, 0, 2, 2, 3, 0, 3, 2, 0, 1, 0, 2, 0, 2, 1, 0, 2, 1,
#        2, 3, 3, 2, 3, 3, 1, 3, 1, 2, 1, 1, 2, 1, 0, 1, 2, 3, 3, 3, 0, 2,
#        1, 0, 3, 2, 3, 1, 3, 1, 1, 2, 2, 3, 0, 1, 1, 2, 1, 0, 2, 3, 3, 3,
#        0, 0, 2, 0, 2, 1, 0, 1, 0, 2, 2, 3, 0, 3, 1, 1, 0, 3, 2, 2, 2, 0,
#        3, 1])

# %% [markdown]
# Split the data set in training and test and apply the SVC with `C=1, kernel='rbf', gamma='auto', class_weight='balanced', decision_function_shape='ovr'`

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model_four = SVC(kernel='rbf', gamma = 'auto', class_weight = 'balanced', 
                 decision_function_shape='ovr', C=1)
model_four
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model_four.fit(X_train, y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# Predict on the test set and plot the confusion matrix, use the `confusion_matrix` function from sklearn and `heatmap` from seaborn. What would be the confusion matrix result of a perfect classification? What information can we extract from it?

# %%
y_pred = model_four.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[13,  0,  0,  0],
#        [ 0, 11,  0,  0],
#        [ 0,  0,  9,  0],
#        [ 0,  0,  0,  7]])

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, y_pred),annot=True,cbar=False)

# %% [markdown]
# Finally compute the accuracy score, what does this value mean?

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %% [markdown]
# You can use the follwing code to visualize the decision function computed by the model.

# %%
def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = plt.contourf(xx, yy, Z, **params)
    return out

X0, X1 = X_test[:, 0], X_test[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(model_four, xx, yy,
               cmap='jet', alpha=0.6)

plt.scatter(X0, X1, c=y_test, cmap='jet', s=20, edgecolors='k')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()

# %% [markdown]
# Now repeat the computations with a linear kernel, what changes do you observe? Now change the `cluster_std` when you generate the data, what would you expecte when you increase it? and when you decrease it?

# %%
#change cluster std to 0.2
X, y = make_blobs(n_samples=200, centers = 4, random_state=0, cluster_std=0.2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model_four_l = SVC(kernel='linear', gamma = 'auto', class_weight = 'balanced', 
                 decision_function_shape='ovr', C=1)
model_four_l
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model_four_l.fit(X_train, y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = model_four_l.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[13,  0,  0,  0],
#        [ 0, 11,  0,  0],
#        [ 0,  0,  9,  0],
#        [ 0,  0,  0,  7]])

# %%
sns.heatmap(confusion_matrix(y_test, y_pred),annot=True,cbar=False)

# %%
X0, X1 = X_test[:, 0], X_test[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(model_four_l, xx, yy,
               cmap='jet', alpha=0.6)

plt.scatter(X0, X1, c=y_test, cmap='jet', s=20, edgecolors='k')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()
